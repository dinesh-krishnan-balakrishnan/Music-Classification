# %% [markdown]
# # Imports

# %%
# Metadata & Audio Access
import os
import utils

# Metadata Management
import pandas as PD

# Record Generation
from multiprocessing import Pool, cpu_count
import tensorflow as TF
from generate_records import worker

# %% [markdown]
# ----
#
# ## Constants

# %%
# Audio Files
TRACKS_FILE = os.path.join(os.getcwd(), 'fma_metadata', 'tracks.csv')
AUDIO_DIR = os.path.join('D:', 'fma_large')

# TFRecord Directories
RECORD_DIR = os.path.join('D:', 'Track_Records')
TRAIN_DIR = os.path.join(RECORD_DIR, 'train')
TEST_DIR = os.path.join(RECORD_DIR, 'test')

# Time
SECONDS = 10
RECORD_SIZE = 1_000

# Multiprocessing Worker Count
N_WORKERS = cpu_count() - 1

# %% [markdown]
# ----
#
# ## Creating the Metadata Dataframe
#
# ### Retrieving Raw Metadata

# %%
# Retrieving track metadata for tracks in 'fma_large'.
tracks = utils.load(TRACKS_FILE)
large_tracks = tracks[tracks['set', 'subset'] <= 'large']

# Retrieving track genres and training/testing classification.
metadata = PD.merge(
    large_tracks['track']['genre_top'], large_tracks['set']['split'], 
    left_index = True, right_index = True
)

metadata['genre_top'].value_counts(ascending = True)
# Out:
# Easy Listening            24
# Blues                    110
# Soul-RnB                 175
# Country                  194
# Spoken                   423
# Old-Time / Historic      554
# Jazz                     571
# Classical               1230
# International           1389
# Instrumental            2079
# Pop                     2332
# Folk                    2803
# Hip-Hop                 3552
# Electronic              9372
# Experimental           10608
# Rock                   14182
# Name: genre_top, dtype: int64

# %% [markdown]
# ### Metadata Processing

# %%
# Due to the data imbalance per genre, genre changes need to be made:
metadata = metadata[metadata['genre_top'].notna()]
metadata['genre_top'] = metadata['genre_top'].replace({
    'Blues'               : 'Jazz & Blues',
    'Soul-RnB'            : 'Jazz & Blues',
    'Jazz'                : 'Jazz & Blues',
    'Easy Listening'      : 'Jazz & Blues',
    'Country'             : 'Folk',
    'Old-Time / Historic' : 'Historic',
})

metadata['genre_top'].value_counts(ascending = True, normalize = True)
# Out:
# Spoken           0.008529
# Historic         0.011170
# Jazz & Blues     0.017743
# Classical        0.024799
# International    0.028005
# Instrumental     0.041917
# Pop              0.047018
# Folk             0.060426
# Hip-Hop          0.071616
# Electronic       0.188959
# Experimental     0.213880
# Rock             0.285939
# Name: genre_top, dtype: float64

# %% [markdown]
# ### Categorical Conversion

# %%
metadata['genre_top'] = metadata['genre_top'].astype('category').cat.codes
metadata['genre_top'].value_counts(ascending = True, normalize = True)
# Out:
# 11    0.008529
# 5     0.011170
# 8     0.017743
# 0     0.024799
# 7     0.028005
# 6     0.041917
# 9     0.047018
# 3     0.060426
# 4     0.071616
# 1     0.188959
# 2     0.213880
# 10    0.285939
# Name: genre_top, dtype: float64

# %% [markdown]
# ----
#
# ## MP3 to TFRecord Conversion
#
# ### Job Generator

# %%
def create_jobs(metadata):
    jobs = []
    
    # Iterates over every track.
    for ID, track in metadata.iterrows():
        
        # Determining audio file pathname and label.
        pathname = utils.get_audio_path(AUDIO_DIR, ID)
        label = track['genre_top']
        
        # Determining how many samples to take from the track.
        # (For dataset balancing)
        for step in range((1 if label in [1, 2, 10] else 3)):
            offset = (step * SECONDS)
            
            jobs.append((pathname, label, offset))
            
    return jobs

# %% [markdown]
# ### Record Creation

# %%
# Creates all records for the given metadata.
def create_records(jobs, training):
    DIR = (TRAIN_DIR if training else TEST_DIR)
    
    # Writing the data in batches of 1000.
    for S in range(0, len(jobs), RECORD_SIZE):
        print(f'ON: {S}')
        
        # Creating the record file and subset job array.
        job_set = jobs[S : (S + RECORD_SIZE)] 
        filename = os.path.join(DIR, f'{S}.tfr')
        
        create_record(job_set, filename)

# Creates a single record for a subset of the metadata.
def create_record(jobs, filename):
    with TF.io.TFRecordWriter(filename) as writer:
        # Creating a small job batch equal to the number of workers.
        for S in range(0, RECORD_SIZE, N_WORKERS):
            job_set = jobs[S : (S + N_WORKERS)]
            write_data(job_set, writer)

# Parses and writes the audio to a TFRecord.
def write_data(jobs, writer):
    with Pool(processes = N_WORKERS) as pool:
        for result in pool.map(worker, jobs):
            # Prints errors & saves TFRecord Examples.
            if isinstance(result, Exception):
                print(result)
            else:
                writer.write(result)

# %% [markdown]
# ### Main Function

# %%
if __name__ == '__main__':
    # Initializing directories.
    for DIR in [RECORD_DIR, TRAIN_DIR, TEST_DIR]:
        if not os.path.exists(DIR):
            os.mkdir(DIR)
    
    # Getting the job lists.
    TRAIN_jobs = create_jobs(metadata[metadata['split'] != 'validation'])
    TEST_jobs = create_jobs(metadata[metadata['split'] == 'validation'])
    
    # Printing total job counts.
    print(f'TRAIN SAMPLES: {len(TRAIN_jobs)}')
    print(f'TEST SAMPLES: {len(TEST_jobs)}')
    print('-------------------------------')
    
    # Generating TFRecord files.
    create_records(TRAIN_jobs, True)
    create_records(TEST_jobs, False)
# Out:
# TRAIN SAMPLES: 72680
# TEST SAMPLES: 7790
# -------------------------------
# ON: 0
# WRONG DIMENSIONS (353, 84) AT 0: D:fma_large\000\000784.mp3
# WRONG DIMENSIONS (204, 84) AT 0: D:fma_large\000\000789.mp3
# WRONG DIMENSIONS (273, 84) AT 0: D:fma_large\000\000794.mp3
# ON: 1000
# WRONG DIMENSIONS (428, 84) AT 0: D:fma_large\001\001176.mp3
#
# ON: 2000
# WRONG DIMENSIONS (353, 84) AT 10: D:fma_large\003\003448.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 3000
#
# ON: 4000
# WRONG DIMENSIONS (218, 84) AT 0: D:fma_large\006\006713.mp3
# WRONG DIMENSIONS (175, 84) AT 0: D:fma_large\008\008325.mp3
# WRONG DIMENSIONS (262, 84) AT 0: D:fma_large\008\008352.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\008\008996.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\008\008997.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\008\008998.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\008\008999.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009000.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009001.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009002.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009003.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009004.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009005.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009006.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009007.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009008.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009009.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009010.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009011.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009012.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009013.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009014.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009015.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009016.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009017.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009018.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009019.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009020.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009021.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009022.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009023.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009024.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009025.mp3
# WRONG DIMENSIONS (344, 84) AT 0: D:fma_large\009\009026.mp3
# WRONG DIMENSIONS (344, 84) AT 0: D:fma_large\009\009027.mp3
# WRONG DIMENSIONS (340, 84) AT 0: D:fma_large\009\009028.mp3
# WRONG DIMENSIONS (340, 84) AT 0: D:fma_large\009\009029.mp3
# WRONG DIMENSIONS (340, 84) AT 0: D:fma_large\009\009030.mp3
# WRONG DIMENSIONS (340, 84) AT 0: D:fma_large\009\009031.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009032.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009033.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009034.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009035.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009036.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009037.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009038.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009039.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009040.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009041.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009042.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009043.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009044.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009045.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009046.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009047.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009048.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009049.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009050.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009051.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009052.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009053.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009054.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009055.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009056.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009057.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009058.mp3
# WRONG DIMENSIONS (347, 84) AT 0: D:fma_large\009\009059.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009062.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009064.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009065.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009066.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009068.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009069.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009070.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009071.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009072.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009073.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009074.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009075.mp3
# WRONG DIMENSIONS (344, 84) AT 0: D:fma_large\009\009076.mp3
# WRONG DIMENSIONS (344, 84) AT 0: D:fma_large\009\009077.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009080.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009081.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009082.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009083.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009084.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009085.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009086.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009087.mp3
# WRONG DIMENSIONS (352, 84) AT 0: D:fma_large\009\009088.mp3
# WRONG DIMENSIONS (352, 84) AT 0: D:fma_large\009\009089.mp3
# WRONG DIMENSIONS (352, 84) AT 0: D:fma_large\009\009090.mp3
# WRONG DIMENSIONS (352, 84) AT 0: D:fma_large\009\009091.mp3
# WRONG DIMENSIONS (352, 84) AT 0: D:fma_large\009\009092.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009093.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009094.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009095.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009096.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009097.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009098.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009099.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009100.mp3
# WRONG DIMENSIONS (367, 84) AT 0: D:fma_large\009\009101.mp3
# WRONG DIMENSIONS (367, 84) AT 0: D:fma_large\009\009102.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009103.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009104.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009105.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009106.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009107.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009108.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009109.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009113.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009114.mp3
# WRONG DIMENSIONS (386, 84) AT 0: D:fma_large\009\009115.mp3
# WRONG DIMENSIONS (346, 84) AT 0: D:fma_large\009\009116.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009117.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009118.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009119.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009120.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009121.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009122.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009123.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009124.mp3
# WRONG DIMENSIONS (345, 84) AT 0: D:fma_large\009\009125.mp3
# WRONG DIMENSIONS (345, 84) AT 0: D:fma_large\009\009126.mp3
# WRONG DIMENSIONS (345, 84) AT 0: D:fma_large\009\009127.mp3
# WRONG DIMENSIONS (345, 84) AT 0: D:fma_large\009\009128.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009129.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009130.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009131.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009132.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009133.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009134.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009135.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009136.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009137.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009138.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009139.mp3
# WRONG DIMENSIONS (380, 84) AT 0: D:fma_large\009\009140.mp3
# WRONG DIMENSIONS (380, 84) AT 0: D:fma_large\009\009141.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009142.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009143.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009144.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009145.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009146.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009147.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009148.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009149.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\009\009150.mp3
# WRONG DIMENSIONS (294, 84) AT 0: D:fma_large\009\009298.mp3
# WRONG DIMENSIONS (262, 84) AT 0: D:fma_large\009\009313.mp3
# WRONG DIMENSIONS (366, 84) AT 0: D:fma_large\009\009314.mp3
# ON: 5000
#
# WRONG DIMENSIONS (401, 84) AT 0: D:fma_large\010\010227.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (262, 84) AT 20: D:fma_large\010\010236.mp3
# WRONG DIMENSIONS (137, 84) AT 10: D:fma_large\010\010245.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (409, 84) AT 10: D:fma_large\010\010248.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (92, 84) AT 10: D:fma_large\010\010257.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (311, 84) AT 20: D:fma_large\010\010272.mp3
# WRONG DIMENSIONS (398, 84) AT 10: D:fma_large\010\010282.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (92, 84) AT 10: D:fma_large\010\010292.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (381, 84) AT 0: D:fma_large\010\010380.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (233, 84) AT 0: D:fma_large\010\010522.mp3
# WRONG DIMENSIONS (340, 84) AT 0: D:fma_large\010\010524.mp3
# WRONG DIMENSIONS (314, 84) AT 0: D:fma_large\010\010526.mp3
# WRONG DIMENSIONS (149, 84) AT 0: D:fma_large\010\010528.mp3
# WRONG DIMENSIONS (145, 84) AT 0: D:fma_large\010\010530.mp3
# WRONG DIMENSIONS (303, 84) AT 0: D:fma_large\010\010532.mp3
# WRONG DIMENSIONS (407, 84) AT 0: D:fma_large\010\010533.mp3
# WRONG DIMENSIONS (138, 84) AT 0: D:fma_large\010\010534.mp3
# WRONG DIMENSIONS (293, 84) AT 0: D:fma_large\010\010536.mp3
# WRONG DIMENSIONS (244, 84) AT 0: D:fma_large\010\010538.mp3
# WRONG DIMENSIONS (186, 84) AT 0: D:fma_large\010\010540.mp3
# WRONG DIMENSIONS (318, 84) AT 0: D:fma_large\010\010542.mp3
# WRONG DIMENSIONS (202, 84) AT 0: D:fma_large\010\010544.mp3
# WRONG DIMENSIONS (240, 84) AT 0: D:fma_large\010\010546.mp3
# WRONG DIMENSIONS (184, 84) AT 0: D:fma_large\010\010548.mp3
# WRONG DIMENSIONS (229, 84) AT 0: D:fma_large\010\010551.mp3
# WRONG DIMENSIONS (311, 84) AT 0: D:fma_large\010\010553.mp3
# WRONG DIMENSIONS (253, 84) AT 0: D:fma_large\010\010555.mp3
# WRONG DIMENSIONS (244, 84) AT 0: D:fma_large\010\010557.mp3
# WRONG DIMENSIONS (295, 84) AT 0: D:fma_large\010\010559.mp3
# WRONG DIMENSIONS (316, 84) AT 0: D:fma_large\010\010931.mp3
# ON: 6000
# WRONG DIMENSIONS (374, 84) AT 10: D:fma_large\011\011519.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (261, 84) AT 0: D:fma_large\011\011755.mp3
# Input signal length=0 is too small to resample from 48000->22050
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (296, 84) AT 0: D:fma_large\011\011756.mp3
# Input signal length=0 is too small to resample from 48000->22050
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (262, 84) AT 0: D:fma_large\011\011798.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# ON: 7000
# WRONG DIMENSIONS (429, 84) AT 0: D:fma_large\012\012075.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\012\012082.mp3
# WRONG DIMENSIONS (81, 84) AT 0: D:fma_large\012\012276.mp3
# WRONG DIMENSIONS (387, 84) AT 20: D:fma_large\012\012512.mp3
#
#
#
# WRONG DIMENSIONS (429, 84) AT 20: D:fma_large\012\012852.mp3
# WRONG DIMENSIONS (429, 84) AT 20: D:fma_large\012\012855.mp3
# WRONG DIMENSIONS (429, 84) AT 20: D:fma_large\012\012883.mp3
# WRONG DIMENSIONS (429, 84) AT 20: D:fma_large\012\012899.mp3
# WRONG DIMENSIONS (429, 84) AT 0: D:fma_large\013\013004.mp3
# ON: 8000
# WRONG DIMENSIONS (355, 84) AT 0: D:fma_large\013\013881.mp3
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\014\014573.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 9000
# WRONG DIMENSIONS (334, 84) AT 20: D:fma_large\015\015151.mp3
# WRONG DIMENSIONS (7, 84) AT 20: D:fma_large\015\015205.mp3
# WRONG DIMENSIONS (176, 84) AT 0: D:fma_large\015\015641.mp3
# ON: 10000
# WRONG DIMENSIONS (330, 84) AT 10: D:fma_large\017\017638.mp3
# can't extend empty axis 0 using modes other than 'constant' or 'empty'
# WRONG DIMENSIONS (400, 84) AT 0: D:fma_large\018\018122.mp3
# ON: 11000
# ON: 12000
# WRONG DIMENSIONS (362, 84) AT 10: D:fma_large\020\020363.mp3
# Input signal length=0 is too small to resample from 44100->22050
#
#
#
# ON: 13000
# WRONG DIMENSIONS (365, 84) AT 0: D:fma_large\023\023366.mp3
# WRONG DIMENSIONS (419, 84) AT 0: D:fma_large\023\023533.mp3
# WRONG DIMENSIONS (111, 84) AT 0: D:fma_large\023\023543.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# ON: 14000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ON: 15000
# WRONG DIMENSIONS (362, 84) AT 20: D:fma_large\026\026746.mp3
# WRONG DIMENSIONS (382, 84) AT 20: D:fma_large\026\026770.mp3
# WRONG DIMENSIONS (175, 84) AT 20: D:fma_large\027\027271.mp3
# ON: 16000
# WRONG DIMENSIONS (210, 84) AT 0: D:fma_large\028\028885.mp3
# WRONG DIMENSIONS (267, 84) AT 0: D:fma_large\029\029029.mp3
# WRONG DIMENSIONS (359, 84) AT 0: D:fma_large\029\029031.mp3
# WRONG DIMENSIONS (152, 84) AT 0: D:fma_large\029\029032.mp3
#
#
#
#
#
#
#
#
#
#
#
#
# WRONG DIMENSIONS (262, 84) AT 20: D:fma_large\029\029418.mp3
# WRONG DIMENSIONS (341, 84) AT 0: D:fma_large\029\029419.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (223, 84) AT 10: D:fma_large\029\029420.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (299, 84) AT 0: D:fma_large\029\029421.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (329, 84) AT 10: D:fma_large\029\029422.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (402, 84) AT 0: D:fma_large\029\029423.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (3, 84) AT 20: D:fma_large\029\029427.mp3
# WRONG DIMENSIONS (175, 84) AT 20: D:fma_large\029\029428.mp3
# WRONG DIMENSIONS (23, 84) AT 20: D:fma_large\029\029429.mp3
# WRONG DIMENSIONS (47, 84) AT 20: D:fma_large\029\029430.mp3
# WRONG DIMENSIONS (278, 84) AT 10: D:fma_large\029\029432.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (261, 84) AT 0: D:fma_large\029\029434.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (265, 84) AT 20: D:fma_large\029\029436.mp3
# WRONG DIMENSIONS (416, 84) AT 0: D:fma_large\029\029437.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (390, 84) AT 10: D:fma_large\029\029438.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 17000
# WRONG DIMENSIONS (305, 84) AT 20: D:fma_large\030\030130.mp3
# WRONG DIMENSIONS (415, 84) AT 20: D:fma_large\030\030207.mp3
# WRONG DIMENSIONS (429, 84) AT 20: D:fma_large\031\031375.mp3
# WRONG DIMENSIONS (411, 84) AT 10: D:fma_large\031\031771.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 18000
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ON: 19000
# WRONG DIMENSIONS (386, 84) AT 0: D:fma_large\036\036102.mp3
# WRONG DIMENSIONS (46, 84) AT 10: D:fma_large\036\036206.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (250, 84) AT 0: D:fma_large\036\036210.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (210, 84) AT 20: D:fma_large\036\036458.mp3
# WRONG DIMENSIONS (369, 84) AT 10: D:fma_large\036\036469.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (128, 84) AT 20: D:fma_large\036\036515.mp3
# WRONG DIMENSIONS (194, 84) AT 20: D:fma_large\036\036517.mp3
# WRONG DIMENSIONS (307, 84) AT 20: D:fma_large\036\036519.mp3
# ON: 20000
# WRONG DIMENSIONS (353, 84) AT 20: D:fma_large\036\036927.mp3
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\036\036993.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 21000
# WRONG DIMENSIONS (393, 84) AT 0: D:fma_large\040\040228.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# ON: 22000
# WRONG DIMENSIONS (304, 84) AT 0: D:fma_large\042\042284.mp3
# WRONG DIMENSIONS (412, 84) AT 0: D:fma_large\042\042352.mp3
# WRONG DIMENSIONS (428, 84) AT 0: D:fma_large\042\042353.mp3
# WRONG DIMENSIONS (321, 84) AT 0: D:fma_large\042\042355.mp3
# WRONG DIMENSIONS (407, 84) AT 0: D:fma_large\042\042358.mp3
# WRONG DIMENSIONS (311, 84) AT 0: D:fma_large\042\042359.mp3
# WRONG DIMENSIONS (368, 84) AT 0: D:fma_large\042\042360.mp3
# WRONG DIMENSIONS (209, 84) AT 0: D:fma_large\042\042361.mp3
# WRONG DIMENSIONS (184, 84) AT 0: D:fma_large\042\042362.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\042\042365.mp3
# WRONG DIMENSIONS (403, 84) AT 0: D:fma_large\042\042366.mp3
# WRONG DIMENSIONS (375, 84) AT 0: D:fma_large\042\042368.mp3
# WRONG DIMENSIONS (400, 84) AT 0: D:fma_large\042\042370.mp3
# WRONG DIMENSIONS (348, 84) AT 0: D:fma_large\042\042371.mp3
# WRONG DIMENSIONS (94, 84) AT 20: D:fma_large\043\043017.mp3
# WRONG DIMENSIONS (259, 84) AT 20: D:fma_large\043\043119.mp3
# WRONG DIMENSIONS (330, 84) AT 20: D:fma_large\043\043241.mp3
# ON: 23000
# WRONG DIMENSIONS (352, 84) AT 0: D:fma_large\043\043634.mp3
# WRONG DIMENSIONS (173, 84) AT 0: D:fma_large\043\043635.mp3
# WRONG DIMENSIONS (352, 84) AT 20: D:fma_large\045\045221.mp3
# WRONG DIMENSIONS (354, 84) AT 0: D:fma_large\045\045226.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (128, 84) AT 20: D:fma_large\045\045227.mp3
# ON: 24000
# WRONG DIMENSIONS (147, 84) AT 0: D:fma_large\045\045949.mp3
# WRONG DIMENSIONS (272, 84) AT 0: D:fma_large\046\046933.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# ON: 25000
# WRONG DIMENSIONS (62, 84) AT 20: D:fma_large\048\048819.mp3
# WRONG DIMENSIONS (393, 84) AT 10: D:fma_large\048\048823.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 26000
# WRONG DIMENSIONS (384, 84) AT 0: D:fma_large\050\050414.mp3
# WRONG DIMENSIONS (47, 84) AT 20: D:fma_large\050\050530.mp3
#
#
#
# WRONG DIMENSIONS (110, 84) AT 20: D:fma_large\050\050903.mp3
# WRONG DIMENSIONS (18, 84) AT 20: D:fma_large\050\050920.mp3
# WRONG DIMENSIONS (55, 84) AT 20: D:fma_large\050\050921.mp3
# WRONG DIMENSIONS (358, 84) AT 20: D:fma_large\050\050922.mp3
# WRONG DIMENSIONS (266, 84) AT 20: D:fma_large\050\050925.mp3
# WRONG DIMENSIONS (67, 84) AT 20: D:fma_large\050\050950.mp3
# WRONG DIMENSIONS (47, 84) AT 0: D:fma_large\051\051334.mp3
# WRONG DIMENSIONS (330, 84) AT 0: D:fma_large\051\051335.mp3
# WRONG DIMENSIONS (424, 84) AT 0: D:fma_large\051\051354.mp3
# ON: 27000
# WRONG DIMENSIONS (372, 84) AT 20: D:fma_large\052\052453.mp3
# WRONG DIMENSIONS (225, 84) AT 10: D:fma_large\054\054030.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 28000
#
#
#
# ON: 29000
# WRONG DIMENSIONS (211, 84) AT 20: D:fma_large\056\056494.mp3
# WRONG DIMENSIONS (151, 84) AT 0: D:fma_large\056\056580.mp3
# WRONG DIMENSIONS (244, 84) AT 0: D:fma_large\056\056594.mp3
# WRONG DIMENSIONS (245, 84) AT 10: D:fma_large\056\056852.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 30000
# WRONG DIMENSIONS (285, 84) AT 0: D:fma_large\057\057729.mp3
# WRONG DIMENSIONS (346, 84) AT 0: D:fma_large\058\058165.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (65, 84) AT 20: D:fma_large\058\058172.mp3
# WRONG DIMENSIONS (359, 84) AT 0: D:fma_large\058\058679.mp3
# WRONG DIMENSIONS (22, 84) AT 20: D:fma_large\058\058808.mp3
# ON: 31000
# WRONG DIMENSIONS (26, 84) AT 20: D:fma_large\060\060046.mp3
# ON: 32000
# WRONG DIMENSIONS (117, 84) AT 10: D:fma_large\060\060601.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 33000
# WRONG DIMENSIONS (307, 84) AT 0: D:fma_large\061\061805.mp3
#
# WRONG DIMENSIONS (267, 84) AT 10: D:fma_large\061\061899.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (49, 84) AT 20: D:fma_large\061\061900.mp3
# WRONG DIMENSIONS (119, 84) AT 0: D:fma_large\063\063160.mp3
# WRONG DIMENSIONS (284, 84) AT 0: D:fma_large\063\063164.mp3
# WRONG DIMENSIONS (305, 84) AT 0: D:fma_large\063\063165.mp3
# WRONG DIMENSIONS (245, 84) AT 0: D:fma_large\063\063166.mp3
# WRONG DIMENSIONS (121, 84) AT 0: D:fma_large\063\063167.mp3
# WRONG DIMENSIONS (264, 84) AT 0: D:fma_large\063\063168.mp3
# WRONG DIMENSIONS (202, 84) AT 0: D:fma_large\063\063169.mp3
# WRONG DIMENSIONS (198, 84) AT 0: D:fma_large\063\063170.mp3
# WRONG DIMENSIONS (217, 84) AT 0: D:fma_large\063\063171.mp3
# WRONG DIMENSIONS (205, 84) AT 0: D:fma_large\063\063172.mp3
# WRONG DIMENSIONS (203, 84) AT 0: D:fma_large\063\063173.mp3
# ON: 34000
# WRONG DIMENSIONS (215, 84) AT 0: D:fma_large\063\063256.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
#
#
#
# WRONG DIMENSIONS (61, 84) AT 20: D:fma_large\063\063752.mp3
# WRONG DIMENSIONS (61, 84) AT 20: D:fma_large\063\063764.mp3
# WRONG DIMENSIONS (304, 84) AT 10: D:fma_large\063\063767.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (99, 84) AT 20: D:fma_large\064\064561.mp3
# ON: 35000
# WRONG DIMENSIONS (385, 84) AT 20: D:fma_large\064\064987.mp3
# WRONG DIMENSIONS (6, 84) AT 10: D:fma_large\065\065642.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 36000
# ON: 37000
# WRONG DIMENSIONS (263, 84) AT 0: D:fma_large\071\071529.mp3
# WRONG DIMENSIONS (247, 84) AT 0: D:fma_large\071\071536.mp3
# ON: 38000
# WRONG DIMENSIONS (121, 84) AT 10: D:fma_large\071\071875.mp3
# Input signal length=0 is too small to resample from 44100->22050
#
# ON: 39000
# WRONG DIMENSIONS (362, 84) AT 0: D:fma_large\075\075098.mp3
# WRONG DIMENSIONS (305, 84) AT 0: D:fma_large\075\075103.mp3
# WRONG DIMENSIONS (262, 84) AT 0: D:fma_large\075\075104.mp3
# WRONG DIMENSIONS (149, 84) AT 0: D:fma_large\075\075105.mp3
# WRONG DIMENSIONS (173, 84) AT 0: D:fma_large\075\075107.mp3
# WRONG DIMENSIONS (155, 84) AT 0: D:fma_large\075\075108.mp3
# WRONG DIMENSIONS (293, 84) AT 0: D:fma_large\075\075109.mp3
# WRONG DIMENSIONS (201, 84) AT 0: D:fma_large\075\075117.mp3
# WRONG DIMENSIONS (319, 84) AT 0: D:fma_large\075\075128.mp3
# WRONG DIMENSIONS (424, 84) AT 0: D:fma_large\075\075139.mp3
# WRONG DIMENSIONS (417, 84) AT 0: D:fma_large\075\075142.mp3
# WRONG DIMENSIONS (342, 84) AT 0: D:fma_large\075\075145.mp3
# WRONG DIMENSIONS (416, 84) AT 0: D:fma_large\075\075153.mp3
# WRONG DIMENSIONS (370, 84) AT 0: D:fma_large\075\075154.mp3
# WRONG DIMENSIONS (293, 84) AT 0: D:fma_large\075\075155.mp3
# WRONG DIMENSIONS (219, 84) AT 0: D:fma_large\075\075156.mp3
# WRONG DIMENSIONS (288, 84) AT 0: D:fma_large\075\075161.mp3
# WRONG DIMENSIONS (282, 84) AT 0: D:fma_large\075\075162.mp3
# WRONG DIMENSIONS (280, 84) AT 0: D:fma_large\075\075163.mp3
# WRONG DIMENSIONS (232, 84) AT 0: D:fma_large\075\075164.mp3
# WRONG DIMENSIONS (260, 84) AT 0: D:fma_large\075\075165.mp3
# WRONG DIMENSIONS (366, 84) AT 0: D:fma_large\075\075166.mp3
# WRONG DIMENSIONS (258, 84) AT 0: D:fma_large\075\075167.mp3
# WRONG DIMENSIONS (311, 84) AT 0: D:fma_large\075\075188.mp3
# WRONG DIMENSIONS (103, 84) AT 0: D:fma_large\075\075189.mp3
# WRONG DIMENSIONS (327, 84) AT 20: D:fma_large\075\075847.mp3
# WRONG DIMENSIONS (252, 84) AT 10: D:fma_large\075\075857.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (245, 84) AT 20: D:fma_large\075\075863.mp3
# ON: 40000
# WRONG DIMENSIONS (130, 84) AT 20: D:fma_large\075\075888.mp3
# WRONG DIMENSIONS (346, 84) AT 10: D:fma_large\078\078515.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (151, 84) AT 20: D:fma_large\078\078986.mp3
# ON: 41000
#
#
#
# ON: 42000
# WRONG DIMENSIONS (326, 84) AT 0: D:fma_large\083\083406.mp3
# WRONG DIMENSIONS (95, 84) AT 20: D:fma_large\084\084160.mp3
# WRONG DIMENSIONS (300, 84) AT 0: D:fma_large\084\084413.mp3
# WRONG DIMENSIONS (267, 84) AT 0: D:fma_large\084\084419.mp3
# WRONG DIMENSIONS (365, 84) AT 0: D:fma_large\084\084424.mp3
# WRONG DIMENSIONS (302, 84) AT 0: D:fma_large\084\084433.mp3
#
#
# ON: 43000
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\086\086348.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (186, 84) AT 20: D:fma_large\086\086349.mp3
# WRONG DIMENSIONS (111, 84) AT 10: D:fma_large\086\086350.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (239, 84) AT 10: D:fma_large\086\086354.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (228, 84) AT 20: D:fma_large\086\086356.mp3
# WRONG DIMENSIONS (277, 84) AT 0: D:fma_large\086\086359.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# ON: 44000
# ON: 45000
# WRONG DIMENSIONS (392, 84) AT 0: D:fma_large\091\091307.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (286, 84) AT 20: D:fma_large\091\091313.mp3
#
#
#
#
#
# ON: 46000
# WRONG DIMENSIONS (104, 84) AT 10: D:fma_large\096\096486.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 47000
# WRONG DIMENSIONS (18, 84) AT 10: D:fma_large\097\097694.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (379, 84) AT 0: D:fma_large\097\097815.mp3
#
#
#
#
#
#
#
#
#
#
#
#
# WRONG DIMENSIONS (70, 84) AT 0: D:fma_large\098\098565.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (269, 84) AT 0: D:fma_large\098\098566.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (22, 84) AT 0: D:fma_large\098\098567.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (283, 84) AT 0: D:fma_large\098\098568.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (66, 84) AT 0: D:fma_large\098\098569.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
#
#
#
#
# ON: 48000
# WRONG DIMENSIONS (56, 84) AT 0: D:fma_large\102\102924.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (225, 84) AT 20: D:fma_large\103\103535.mp3
# ON: 49000
#
#
#
#
# ON: 50000
# WRONG DIMENSIONS (410, 84) AT 10: D:fma_large\107\107818.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (56, 84) AT 20: D:fma_large\108\108013.mp3
# WRONG DIMENSIONS (398, 84) AT 10: D:fma_large\108\108458.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (328, 84) AT 10: D:fma_large\108\108713.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (337, 84) AT 10: D:fma_large\108\108723.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (394, 84) AT 10: D:fma_large\108\108742.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (364, 84) AT 10: D:fma_large\108\108751.mp3
# Input signal length=0 is too small to resample from 48000->22050
# ON: 51000
#
#
#
# WRONG DIMENSIONS (255, 84) AT 20: D:fma_large\110\110745.mp3
# ON: 52000
# ON: 53000
# WRONG DIMENSIONS (312, 84) AT 0: D:fma_large\113\113593.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\113\113650.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (25, 84) AT 10: D:fma_large\113\113651.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (229, 84) AT 10: D:fma_large\113\113657.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\113\113658.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (16, 84) AT 10: D:fma_large\113\113664.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (81, 84) AT 10: D:fma_large\113\113665.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (84, 84) AT 10: D:fma_large\113\113666.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (81, 84) AT 10: D:fma_large\113\113667.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (79, 84) AT 10: D:fma_large\113\113668.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (148, 84) AT 10: D:fma_large\113\113669.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\113\113671.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\113\113689.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\113\113726.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (140, 84) AT 10: D:fma_large\113\113798.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (198, 84) AT 10: D:fma_large\113\113931.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (101, 84) AT 10: D:fma_large\113\113944.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\113\113945.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (119, 84) AT 10: D:fma_large\113\113951.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (229, 84) AT 10: D:fma_large\113\113952.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\113\113966.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (153, 84) AT 10: D:fma_large\113\113983.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (213, 84) AT 10: D:fma_large\113\113986.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (203, 84) AT 10: D:fma_large\114\114003.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (404, 84) AT 0: D:fma_large\114\114005.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\114\114016.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\114\114060.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (200, 84) AT 10: D:fma_large\114\114081.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (212, 84) AT 10: D:fma_large\114\114083.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114088.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (229, 84) AT 10: D:fma_large\114\114089.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (235, 84) AT 10: D:fma_large\114\114090.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (208, 84) AT 10: D:fma_large\114\114091.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (242, 84) AT 10: D:fma_large\114\114092.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114093.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114094.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114095.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114097.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (222, 84) AT 10: D:fma_large\114\114098.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114099.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (220, 84) AT 10: D:fma_large\114\114101.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114102.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (211, 84) AT 10: D:fma_large\114\114103.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (164, 84) AT 10: D:fma_large\114\114104.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114105.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (196, 84) AT 10: D:fma_large\114\114106.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (236, 84) AT 10: D:fma_large\114\114107.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (123, 84) AT 10: D:fma_large\114\114108.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (169, 84) AT 10: D:fma_large\114\114109.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (247, 84) AT 10: D:fma_large\114\114110.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (240, 84) AT 10: D:fma_large\114\114111.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (74, 84) AT 10: D:fma_large\114\114113.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (85, 84) AT 10: D:fma_large\114\114114.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (60, 84) AT 10: D:fma_large\114\114115.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (182, 84) AT 10: D:fma_large\114\114116.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (276, 84) AT 0: D:fma_large\114\114197.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (254, 84) AT 10: D:fma_large\114\114229.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (203, 84) AT 10: D:fma_large\114\114256.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (391, 84) AT 0: D:fma_large\114\114257.mp3
# Input signal length=0 is too small to resample from 48000->22050
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (154, 84) AT 10: D:fma_large\114\114258.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (424, 84) AT 0: D:fma_large\114\114259.mp3
# Input signal length=0 is too small to resample from 48000->22050
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (96, 84) AT 10: D:fma_large\114\114260.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (84, 84) AT 10: D:fma_large\114\114261.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (181, 84) AT 10: D:fma_large\114\114262.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (186, 84) AT 10: D:fma_large\114\114263.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\114\114264.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (212, 84) AT 10: D:fma_large\114\114277.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (220, 84) AT 10: D:fma_large\114\114368.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (44, 84) AT 0: D:fma_large\114\114369.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (44, 84) AT 0: D:fma_large\114\114370.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# ON: 54000
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114447.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (212, 84) AT 10: D:fma_large\114\114449.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (377, 84) AT 0: D:fma_large\114\114458.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (208, 84) AT 10: D:fma_large\114\114469.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (212, 84) AT 10: D:fma_large\114\114470.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (201, 84) AT 10: D:fma_large\114\114489.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (213, 84) AT 10: D:fma_large\114\114490.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (404, 84) AT 0: D:fma_large\114\114491.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (205, 84) AT 10: D:fma_large\114\114492.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (239, 84) AT 10: D:fma_large\114\114493.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (144, 84) AT 10: D:fma_large\114\114494.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (17, 84) AT 0: D:fma_large\114\114497.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (177, 84) AT 0: D:fma_large\114\114498.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (177, 84) AT 0: D:fma_large\114\114503.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (361, 84) AT 0: D:fma_large\114\114504.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (263, 84) AT 0: D:fma_large\114\114517.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (252, 84) AT 0: D:fma_large\114\114526.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (372, 84) AT 0: D:fma_large\114\114527.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (257, 84) AT 0: D:fma_large\114\114530.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\114\114542.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (153, 84) AT 10: D:fma_large\114\114543.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (182, 84) AT 10: D:fma_large\114\114557.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (178, 84) AT 10: D:fma_large\114\114561.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\114\114562.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\114\114568.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (185, 84) AT 10: D:fma_large\114\114569.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (204, 84) AT 0: D:fma_large\114\114570.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (211, 84) AT 10: D:fma_large\114\114573.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (174, 84) AT 10: D:fma_large\114\114574.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (166, 84) AT 0: D:fma_large\114\114575.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (45, 84) AT 10: D:fma_large\114\114577.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (189, 84) AT 10: D:fma_large\114\114578.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (211, 84) AT 10: D:fma_large\114\114585.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\114\114597.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\114\114598.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\114\114649.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (180, 84) AT 10: D:fma_large\114\114660.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\114\114661.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114662.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114663.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\114\114664.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\114\114665.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (93, 84) AT 10: D:fma_large\114\114666.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (183, 84) AT 10: D:fma_large\114\114685.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (213, 84) AT 10: D:fma_large\114\114696.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (157, 84) AT 10: D:fma_large\114\114717.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (212, 84) AT 10: D:fma_large\114\114718.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (323, 84) AT 0: D:fma_large\114\114719.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (323, 84) AT 0: D:fma_large\114\114720.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (323, 84) AT 0: D:fma_large\114\114721.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (213, 84) AT 10: D:fma_large\114\114767.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (171, 84) AT 10: D:fma_large\114\114768.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (220, 84) AT 10: D:fma_large\114\114772.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (158, 84) AT 10: D:fma_large\114\114775.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114789.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114792.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114794.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (209, 84) AT 10: D:fma_large\114\114800.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (182, 84) AT 10: D:fma_large\114\114807.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (231, 84) AT 10: D:fma_large\114\114848.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114849.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (85, 84) AT 10: D:fma_large\114\114850.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (240, 84) AT 10: D:fma_large\114\114851.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\114\114852.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ...
# WRONG DIMENSIONS (201, 84) AT 10: D:fma_large\115\115326.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (68, 84) AT 10: D:fma_large\115\115327.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (194, 84) AT 10: D:fma_large\115\115328.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115329.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\115\115330.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\115\115331.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (208, 84) AT 10: D:fma_large\115\115333.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (241, 84) AT 10: D:fma_large\115\115334.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (83, 84) AT 10: D:fma_large\115\115335.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (90, 84) AT 10: D:fma_large\115\115336.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115337.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115338.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\115\115341.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (211, 84) AT 10: D:fma_large\115\115342.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (208, 84) AT 10: D:fma_large\115\115343.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\115\115344.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (185, 84) AT 10: D:fma_large\115\115345.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (185, 84) AT 10: D:fma_large\115\115346.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (336, 84) AT 0: D:fma_large\115\115347.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (332, 84) AT 0: D:fma_large\115\115349.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (168, 84) AT 10: D:fma_large\115\115350.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (168, 84) AT 10: D:fma_large\115\115351.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\115\115352.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (201, 84) AT 10: D:fma_large\115\115353.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (89, 84) AT 10: D:fma_large\115\115355.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (133, 84) AT 0: D:fma_large\115\115393.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (36, 84) AT 10: D:fma_large\115\115394.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (217, 84) AT 10: D:fma_large\115\115398.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\115\115399.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\115\115400.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\115\115401.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\115\115402.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\115\115405.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\115\115406.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\115\115407.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\115\115408.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\115\115409.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115493.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (230, 84) AT 10: D:fma_large\115\115494.mp3
# ON: 55000
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115495.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115496.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115497.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115498.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115499.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115500.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115501.mp3
# Input signal length=0 is too small to resample from 32000->22050
# WRONG DIMENSIONS (97, 84) AT 10: D:fma_large\115\115503.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115504.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (156, 84) AT 10: D:fma_large\115\115505.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (129, 84) AT 10: D:fma_large\115\115507.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (164, 84) AT 10: D:fma_large\115\115508.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (34, 84) AT 10: D:fma_large\115\115510.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (202, 84) AT 10: D:fma_large\115\115511.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (217, 84) AT 10: D:fma_large\115\115512.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (133, 84) AT 0: D:fma_large\115\115513.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (175, 84) AT 10: D:fma_large\115\115515.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (236, 84) AT 10: D:fma_large\115\115517.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (208, 84) AT 10: D:fma_large\115\115518.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (178, 84) AT 20: D:fma_large\115\115889.mp3
# WRONG DIMENSIONS (188, 84) AT 0: D:fma_large\116\116696.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (188, 84) AT 0: D:fma_large\116\116705.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (419, 84) AT 20: D:fma_large\117\117154.mp3
# ON: 56000
# ON: 57000
# WRONG DIMENSIONS (246, 84) AT 0: D:fma_large\119\119995.mp3
# Input signal length=0 is too small to resample from 44100->22050
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 20: D:fma_large\120\120880.mp3
# ON: 58000
# WRONG DIMENSIONS (348, 84) AT 10: D:fma_large\122\122643.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 59000
# ON: 60000
# WRONG DIMENSIONS (335, 84) AT 10: D:fma_large\125\125601.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (401, 84) AT 10: D:fma_large\125\125602.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (355, 84) AT 20: D:fma_large\125\125658.mp3
# ON: 61000
#
#
#
# WRONG DIMENSIONS (241, 84) AT 20: D:fma_large\127\127011.mp3
#
# WRONG DIMENSIONS (300, 84) AT 0: D:fma_large\127\127348.mp3
# WRONG DIMENSIONS (407, 84) AT 0: D:fma_large\127\127718.mp3
# ON: 62000
# ON: 63000
# WRONG DIMENSIONS (79, 84) AT 20: D:fma_large\131\131440.mp3
#
#
#
# WRONG DIMENSIONS (358, 84) AT 20: D:fma_large\131\131921.mp3
# ON: 64000
# WRONG DIMENSIONS (175, 84) AT 0: D:fma_large\132\132325.mp3
# WRONG DIMENSIONS (173, 84) AT 0: D:fma_large\132\132328.mp3
# WRONG DIMENSIONS (198, 84) AT 0: D:fma_large\132\132332.mp3
# WRONG DIMENSIONS (214, 84) AT 0: D:fma_large\132\132335.mp3
# WRONG DIMENSIONS (173, 84) AT 0: D:fma_large\132\132339.mp3
# WRONG DIMENSIONS (190, 84) AT 0: D:fma_large\132\132343.mp3
# WRONG DIMENSIONS (316, 84) AT 0: D:fma_large\132\132418.mp3
#
# WRONG DIMENSIONS (305, 84) AT 20: D:fma_large\133\133534.mp3
# WRONG DIMENSIONS (362, 84) AT 10: D:fma_large\133\133539.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (118, 84) AT 20: D:fma_large\133\133540.mp3
# WRONG DIMENSIONS (139, 84) AT 20: D:fma_large\133\133549.mp3
# WRONG DIMENSIONS (251, 84) AT 20: D:fma_large\133\133552.mp3
# WRONG DIMENSIONS (271, 84) AT 20: D:fma_large\133\133568.mp3
# WRONG DIMENSIONS (190, 84) AT 20: D:fma_large\133\133569.mp3
# WRONG DIMENSIONS (389, 84) AT 10: D:fma_large\133\133938.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 65000
# WRONG DIMENSIONS (249, 84) AT 10: D:fma_large\134\134954.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 66000
# ON: 67000
# ON: 68000
#
# ON: 69000
# WRONG DIMENSIONS (317, 84) AT 0: D:fma_large\147\147813.mp3
# WRONG DIMENSIONS (399, 84) AT 10: D:fma_large\148\148115.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (354, 84) AT 20: D:fma_large\148\148117.mp3
# WRONG DIMENSIONS (420, 84) AT 20: D:fma_large\148\148122.mp3
# WRONG DIMENSIONS (290, 84) AT 20: D:fma_large\148\148128.mp3
# WRONG DIMENSIONS (290, 84) AT 20: D:fma_large\148\148129.mp3
# ON: 70000
#
#
#
#
#
#
#
#
#
#
# WRONG DIMENSIONS (424, 84) AT 0: D:fma_large\149\149939.mp3
# WRONG DIMENSIONS (179, 84) AT 10: D:fma_large\150\150012.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 71000
# WRONG DIMENSIONS (325, 84) AT 10: D:fma_large\151\151846.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (425, 84) AT 10: D:fma_large\151\151848.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (203, 84) AT 0: D:fma_large\153\153362.mp3
# WRONG DIMENSIONS (275, 84) AT 20: D:fma_large\153\153373.mp3
# WRONG DIMENSIONS (85, 84) AT 20: D:fma_large\153\153381.mp3
# ON: 72000
# ON: 0
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009078.mp3
# WRONG DIMENSIONS (349, 84) AT 0: D:fma_large\009\009079.mp3
# ON: 1000
# WRONG DIMENSIONS (212, 84) AT 20: D:fma_large\019\019703.mp3
# ON: 2000
# WRONG DIMENSIONS (261, 84) AT 20: D:fma_large\041\041376.mp3
# WRONG DIMENSIONS (411, 84) AT 10: D:fma_large\041\041389.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (369, 84) AT 20: D:fma_large\042\042910.mp3
# WRONG DIMENSIONS (139, 84) AT 20: D:fma_large\051\051279.mp3
# WRONG DIMENSIONS (226, 84) AT 10: D:fma_large\051\051285.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (259, 84) AT 20: D:fma_large\051\051287.mp3
# ON: 3000
#
#
#
# WRONG DIMENSIONS (385, 84) AT 10: D:fma_large\059\059444.mp3
# Input signal length=0 is too small to resample from 44100->22050
#
# ON: 4000
# WRONG DIMENSIONS (290, 84) AT 20: D:fma_large\075\075382.mp3
# WRONG DIMENSIONS (302, 84) AT 10: D:fma_large\075\075402.mp3
# Input signal length=0 is too small to resample from 44100->22050
#
# ON: 5000
# WRONG DIMENSIONS (414, 84) AT 0: D:fma_large\091\091545.mp3
# WRONG DIMENSIONS (353, 84) AT 0: D:fma_large\091\091547.mp3
# WRONG DIMENSIONS (239, 84) AT 0: D:fma_large\091\091552.mp3
# WRONG DIMENSIONS (200, 84) AT 10: D:fma_large\113\113773.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (211, 84) AT 10: D:fma_large\113\113775.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (217, 84) AT 10: D:fma_large\113\113776.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\113\113777.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (215, 84) AT 10: D:fma_large\113\113985.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (214, 84) AT 10: D:fma_large\114\114117.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (201, 84) AT 10: D:fma_large\114\114311.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\114\114318.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (34, 84) AT 10: D:fma_large\114\114560.mp3
# Input signal length=0 is too small to resample from 44100->22050
# ON: 6000
# WRONG DIMENSIONS (213, 84) AT 10: D:fma_large\114\114594.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (175, 84) AT 10: D:fma_large\114\114595.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (226, 84) AT 10: D:fma_large\114\114596.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (218, 84) AT 10: D:fma_large\114\114791.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114979.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (250, 84) AT 10: D:fma_large\114\114980.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (216, 84) AT 10: D:fma_large\114\114981.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (219, 84) AT 10: D:fma_large\115\115098.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (143, 84) AT 10: D:fma_large\115\115113.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (47, 84) AT 10: D:fma_large\115\115114.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (245, 84) AT 10: D:fma_large\115\115132.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (227, 84) AT 10: D:fma_large\115\115133.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (245, 84) AT 10: D:fma_large\115\115134.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (175, 84) AT 10: D:fma_large\115\115156.mp3
# Input signal length=0 is too small to resample from 44100->22050
# WRONG DIMENSIONS (87, 84) AT 10: D:fma_large\115\115476.mp3
# Input signal length=0 is too small to resample from 48000->22050
# WRONG DIMENSIONS (325, 84) AT 20: D:fma_large\119\119327.mp3
# ON: 7000
# WRONG DIMENSIONS (325, 84) AT 20: D:fma_large\143\143980.mp3
# WRONG DIMENSIONS (389, 84) AT 0: D:fma_large\155\155006.mp3
# WRONG DIMENSIONS (416, 84) AT 0: D:fma_large\155\155014.mp3

# %% [markdown]
# ----
#
# ## Balanced/Unbalanced Data Check

# %%
# TFRecord Structure
FEATURE_STRUCTURE = {
    'parameters': TF.io.FixedLenFeature([430 * 84], TF.float32),
    'label': TF.io.FixedLenFeature([], TF.int64)
}

# Parses Byte Values
def parse_dataset(feature):
    data = TF.io.parse_single_example(feature, FEATURE_STRUCTURE)
    return data['label']

# Retrieves categorical label counts.
def dataset_count(DIR):
    # 12 Labels Total
    category_counts = [0] * 12
    
    # Parses all files in the specified directory.
    for file in os.listdir(DIR):
        # Parsing
        dataset = TF.data.TFRecordDataset(os.path.join(DIR, file))
        dataset = dataset.map(
            parse_dataset,
            num_parallel_calls = TF.data.experimental.AUTOTUNE,
            deterministic = False
        )

        # Adding to the counter.
        for element in iter(dataset):
            category_counts[element] += 1

    # Logging Results
    print(category_counts)
    print(sum(category_counts))
        
dataset_count(TRAIN_DIR)
dataset_count(TEST_DIR)
# Out:
# [3450, 8320, 9571, 8195, 9624, 1482, 5600, 3712, 2353, 5401, 12809, 904]
# 71421
# [222, 865, 964, 741, 953, 162, 573, 408, 282, 880, 1323, 341]
# 7714
